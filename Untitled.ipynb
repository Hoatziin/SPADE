# %%
# %run stock_pred.py
# Out:
# 2022-05-31 11:15:46.780082: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 927/927 - 8s - loss: 9.3426e-04 - 8s/epoch - 8ms/step
# 8/8 [==============================] - 0s 5ms/step
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/indexes/base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File pandas/_libs/index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# ...

# %%
# %run stock_pred.py
# Out:
# 927/927 - 8s - loss: 0.0013 - 8s/epoch - 8ms/step
# 8/8 [==============================] - 0s 5ms/step
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/indexes/base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File pandas/_libs/index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Predictions'
#
# ...

# %%
# %run stock_app.py
# Out:
# 8/8 [==============================] - 0s 5ms/step
# Dash is running on http://127.0.0.1:8050/
#
#  * Serving Flask app 'stock_app' (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: on
# 2022-05-31 11:18:28.956207: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 8/8 [==============================] - 0s 5ms/step

# %%
# %run stock_app,py
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/IPython/core/magics/execution.py:696, in ExecutionMagics.run(self, parameter_s, runner, file_finder)
#     695     fpath = arg_lst[0]
# --> 696     filename = file_finder(fpath)
#     697 except IndexError as e:
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/IPython/utils/path.py:91, in get_py_filename(name)
#      90 else:
# ---> 91     raise IOError('File `%r` not found.' % name)
#
# OSError: File `'stock_app,py.py'` not found.
#
# The above exception was the direct cause of the following exception:
#
# Exception                                 Traceback (most recent call last)
# Input In [6], in <cell line: 1>()
# ----> 1 get_ipython().run_line_magic('run', 'stock_app,py')
#
# ...

# %%
# %run stock_app.py
# Out:
# 8/8 [==============================] - 0s 5ms/step
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
#  * Serving Flask app 'stock_app' (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: on
# /Users/gregorylamoreaux/Desktop/SPADE/stock_app.py:70: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   valid['Predictions']=closing_price
# 2022-05-31 11:20:18.681703: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 8/8 [==============================] - 0s 5ms/step
# ...

# %%
# %run stock_app.py
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/sklearn/preprocessing/_data.py:464: RuntimeWarning: All-NaN slice encountered
#   data_min = np.nanmin(X, axis=0)
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/sklearn/preprocessing/_data.py:465: RuntimeWarning: All-NaN slice encountered
#   data_max = np.nanmax(X, axis=0)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/Desktop/SPADE/stock_app.py:57, in <module>
#      55 inputs=new_data[len(new_data)-len(valid)-60:].values
#      56 inputs=inputs.reshape(-1,1)
# ---> 57 inputs=scaler.transform(inputs)
#      59 X_test=[]
#      60 for i in range(60,inputs.shape[0]):
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/sklearn/preprocessing/_data.py:499, in MinMaxScaler.transform(self, X)
# ...

# %%
# %run stock_app.py
# Out:
# 8/8 [==============================] - 0s 5ms/step
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# File ~/Desktop/SPADE/stock_app.py:70, in <module>
#      68 train=new_data[:987]
#      69 valid=new_data[987:]
# ---> 70 valid.insert(2,"Predictions", closing_price, True)
#      74 df= pd.read_csv("./stock_data.csv")
#      76 app.layout = html.Div([
#      77
#      78     html.H1("Stock Price Analysis Dashboard", style={"textAlign": "center"}),
#    (...)
#     157     ])
#     158 ])
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/frame.py:4445, in DataFrame.insert(self, loc, column, value, allow_duplicates)
#    4442     raise TypeError("loc must be int")
#    4444 value = self._sanitize_column(value)
# -> 4445 self._mgr.insert(loc, column, value)
#
# ...

# %%
# %run stock_app.py
# Out:
# 8/8 [==============================] - 0s 5ms/step
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
#  * Serving Flask app 'stock_app' (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: on
# 2022-05-31 11:27:21.078377: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 8/8 [==============================] - 0s 5ms/step

# %%
# %run stock_pred.py
# Out:
# KeyboardInterrupt

# %%
# %run stock_pred.py
# Out:
# 927/927 - 8s - loss: 0.0011 - 8s/epoch - 8ms/step
# 8/8 [==============================] - 0s 5ms/step
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/indexes/base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File pandas/_libs/index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Predictions'
#
# ...

# %%
# %run stock_pred.py
# Out:
#   File ~/Desktop/SPADE/stock_pred.py:76
#     predicted_closing_price=scaler.inverse_transform(predicted_closing_price
#                                                     ^
# SyntaxError: '(' was never closed

# %%
# %run stock_pred.py
# Out:
# 927/927 - 8s - loss: 0.0013 - 8s/epoch - 8ms/step
# 8/8 [==============================] - 0s 5ms/step

# %%
# %run stock_app.py
# Out:
# 8/8 [==============================] - 0s 5ms/step
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
#  * Serving Flask app 'stock_app' (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: on
# 2022-05-31 11:33:42.981169: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 8/8 [==============================] - 0s 5ms/step
# /Users/gregorylamoreaux/Desktop/SPADE/stock_app.py:2: UserWarning:
# The dash_core_components package is deprecated. Please replace
# `import dash_core_components as dcc` with `from dash import dcc`
#   import dash_core_components as dcc
# ...

# %%
# %run stock_app.py
# Out:
# /Users/gregorylamoreaux/Desktop/SPADE/stock_app.py:2: UserWarning:
# The dash_core_components package is deprecated. Please replace
# `import dash_core_components as dcc` with `from dash import dcc`
#   from dash import dcc
# /Users/gregorylamoreaux/Desktop/SPADE/stock_app.py:3: UserWarning:
# The dash_html_components package is deprecated. Please replace
# `import dash_html_components as html` with `from dash import html`
#   from dash import html
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# File ~/Desktop/SPADE/stock_app.py:35, in <module>
#      33 x_train,y_train=np.array(x_train),np.array(y_train)
#      34 x_train=np.reshape(x_train,(x_train.shape[0],x_train.shape[1],1))
# ---> 35 model=load_model("saved_model.h5")
#      36 inputs=new_data[len(new_data)-len(valid)-60:].values
#      37 inputs=inputs.reshape(-1,1)
#
# ...

# %%
# %run stock_app.py

# %%
# %run stock_app.py

# %%
python3 stock_app.py
# Out:
#   Input In [1]
#     python3 stock_app.py
#             ^
# SyntaxError: invalid syntax

# %%
# %run stock_app.py
# Out:
#   File ~/Desktop/SPADE/stock_app.py:237
#     app.run_server(debug=True)
#     ^
# TabError: inconsistent use of tabs and spaces in indentation

# %%
# %run stock_app.py
# Out:
#   File ~/Desktop/SPADE/stock_app.py:237
#     print("eeeee");
#                    ^
# IndentationError: unindent does not match any outer indentation level

# %%
# %run stock_app.py
# Out:
# 8/8 [==============================] - 0s 5ms/step
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
#  * Serving Flask app 'stock_app' (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: on
# 2022-05-31 11:54:22.845784: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 8/8 [==============================] - 0s 5ms/step

# %%
# %run stock_pred.py
# Out:
# 2022-06-01 10:23:23.063097: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 927/927 - 8s - loss: 0.0012 - 8s/epoch - 8ms/step
# 8/8 [==============================] - 0s 5ms/step

# %%
# %run stock_pred.py
# Out:
# 927/927 - 8s - loss: 0.0012 - 8s/epoch - 8ms/step
# 8/8 [==============================] - 0s 5ms/step
# 927/927 - 8s - loss: 4.6118e-05 - 8s/epoch - 9ms/step
# 231/231 [==============================] - 2s 5ms/step

# %%
# %run stock_pred.py
# Out:
# 927/927 - 8s - loss: 0.0011 - 8s/epoch - 8ms/step
# 8/8 [==============================] - 0s 5ms/step
# 927/927 - 8s - loss: 0.0455 - 8s/epoch - 8ms/step
# 1/1 [==============================] - 0s 298ms/step

# %%
# %run stock_pred.py
# Out:
# 927/927 - 8s - loss: 0.0012 - 8s/epoch - 8ms/step
# 8/8 [==============================] - 1s 5ms/step
# 927/927 - 8s - loss: 0.0048 - 8s/epoch - 9ms/step
# 8/8 [==============================] - 0s 5ms/step
# 927/927 - 8s - loss: 0.0024 - 8s/epoch - 8ms/step
# 14/14 [==============================] - 0s 5ms/step

# %%
# %run stock_pred.py
# Out:
# 927/927 - 8s - loss: 0.0013 - 8s/epoch - 8ms/step
# 8/8 [==============================] - 0s 5ms/step
# 927/927 - 8s - loss: 4.2099e-06 - 8s/epoch - 8ms/step
# 231/231 [==============================] - 1s 5ms/step
# 927/927 - 8s - loss: 0.0031 - 8s/epoch - 8ms/step
# 14/14 [==============================] - 0s 5ms/step

# %%
# %run stock_pred.py
# Out:
# 927/927 - 8s - loss: 0.0010 - 8s/epoch - 8ms/step
# 8/8 [==============================] - 0s 8ms/step
# 927/927 - 8s - loss: 3.3042e-06 - 8s/epoch - 8ms/step
# 231/231 [==============================] - 1s 5ms/step
# 927/927 - 8s - loss: 0.0027 - 8s/epoch - 8ms/step
# 14/14 [==============================] - 0s 5ms/step

# %%
# %run stock_pred.py
# Out:
# 927/927 - 8s - loss: 0.0010 - 8s/epoch - 8ms/step
# 8/8 [==============================] - 0s 5ms/step
# 3940/3940 - 29s - loss: 1.9579e-06 - 29s/epoch - 7ms/step
# 137/137 [==============================] - 1s 5ms/step
# 1440/1440 - 11s - loss: 0.0020 - 11s/epoch - 8ms/step
# 12/12 [==============================] - 0s 5ms/step
